# %%
import leafmap.foliumap as leafmap
import geopandas as gpd

# Standard library imports
import json
import os
from pathlib import Path
import re
import urllib3


# Third-party imports
import dask
import dask.distributed
import dask.utils
from datacube.utils.cog import write_cog
from dotenv import load_dotenv
import geopandas as gpd
import numpy as np
from odc.stac import configure_rio, stac_load
import pandas as pd
import planetary_computer as pc
from pystac_client import Client
import rasterio as rio
from rasterio.mask import mask as rio_mask
from rasterio.session import AWSSession
import xarray as xr
from IPython.display import display



print("Load environment variables from .env file.")
load_dotenv()
USGS_API_KEY = os.environ["USGS_API_KEY"]
USGS_TOKEN_NAME = os.environ["USGS_TOKEN_NAME"]
USGS_USERNAME = os.environ["USGS_USERNAME"]
USGS_PASSWORD = os.environ["USGS_PASSWORD"]
AWS_ACCESS_KEY = os.environ["AWS_ACCESS_KEY"]
AWS_SECRET_KEY = os.environ["AWS_SECRET_KEY"]
NASA_EARTHDATA_S3_ACCESS_KEY = os.environ["NASA_EARTHDATA_S3_ACCESS_KEY"]
NASA_EARTHDATA_S3_SECRET_KEY = os.environ["NASA_EARTHDATA_S3_SECRET_KEY"]
NASA_EARTHDATA_S3_SESSION = os.environ["NASA_EARTHDATA_S3_SESSION"]
NASA_EARTHDATA_USERNAME = os.environ["NASA_EARTHDATA_USERNAME"]
NASA_EARTHDATA_PASSWORD = os.environ["NASA_EARTHDATA_PASSWORD"]

DATA_DIR = Path(r"C:\Users\Peter\gh\rasmussen-705.603\data\FinalProject")
RES = 10
STAC_ENDPOINT = "https://planetarycomputer.microsoft.com/api/stac/v1"
COLLECTIONS = ["sentinel-2-l2a"]
COLLECTION_BANDS = ["blue", "green", "red", "nir08", "swir16", "swir22", "qa"]
OUTPUT_BANDS = ["blue", "green", "red", "nir08", "swir16", "swir22", "ndvi", "qa"]

os.environ["GDAL_DISABLE_READDIR_ON_OPEN"] = "FALSE"


# Define directory paths
raw_dir = DATA_DIR / "raw"
interim_dir = DATA_DIR / "interim"
processed_dir = DATA_DIR / "processed"
region_dir = raw_dir / "regions"
maxar_cogs_dir = interim_dir / "maxar_cogs"
maxar_cogs_dir.mkdir(exist_ok=True, parents=True)
dst_dir = interim_dir / "cogs"
dst_dir.mkdir(exist_ok=True, parents=True)
# Out:
# Load environment variables from .env file.

# %%
leafmap.maxar_collections()
# Out:
# ['Gambia-flooding-8-11-2022',
#  'Hurricane-Fiona-9-19-2022',
#  'Hurricane-Ian-9-26-2022',
#  'Indonesia-Earthquake22',
#  'Kahramanmaras-turkey-earthquake-23',
#  'New-Zealand-Flooding22',
#  'New-Zealand-Flooding23',
#  'Sudan-flooding-8-22-2022',
#  'afghanistan-earthquake22',
#  'cyclone-emnati22',
#  'kentucky-flooding-7-29-2022',
#  'pakistan-flooding22',
#  'southafrica-flooding22',
#  'tonga-volcano21',
#  'volcano-indonesia21',
#  'yellowstone-flooding22']

# %%
regions
# Out:
#                                               event_key  a2  event_date
# maxar_event
# afghanistan-earthquake22              af-kharkamar-2022  af  2022-06-21  \
# Gambia-flooding-8-11-2022              gm-kanifing-2022  gm  2022-08-09
# Indonesia-Earthquake22                  in-cianjur-2022  in  2022-11-21
# cyclone-emnati22                    mg-farafangana-2022  mg  2022-02-22
# Kahramanmaras-turkey-earthquake-23     tr-islahiye-2023  tr  2023-02-06
# NaN                                   us-baltimore-9999  us  2021-02-06
#
#                                       s2_start      s2_end
# maxar_event
# afghanistan-earthquake22            2016-01-01  2023-04-29  \
# Gambia-flooding-8-11-2022           2016-01-01  2023-04-29
# Indonesia-Earthquake22              2016-01-01  2023-04-29
# cyclone-emnati22                    2016-01-01  2023-04-29
# Kahramanmaras-turkey-earthquake-23  2016-01-01  2023-04-29
# NaN                                 2016-01-01  2023-04-29
#
#                                                                              geometry
# maxar_event
# afghanistan-earthquake22            POLYGON ((69.81754 32.97436, 69.81754 32.96162...
# Gambia-flooding-8-11-2022           POLYGON ((-16.68547 13.47630, -16.68547 13.423...
# Indonesia-Earthquake22              POLYGON ((107.11600 -6.79750, 107.11600 -6.849...
# cyclone-emnati22                    POLYGON ((47.83751 -22.82598, 47.83751 -22.810...
# Kahramanmaras-turkey-earthquake-23  POLYGON ((36.64975 37.03872, 36.61874 37.03872...
# NaN                                 POLYGON ((-76.65257 39.31924, -76.65257 39.270...

# %%
import leafmap
regions = gpd.read_file(raw_dir / "regions.geojson").dropna().set_index("maxar_event")
events = regions.index.values


for event in events:
    collections = leafmap.maxar_child_collections(event)
    print(f"[Download Maxar][{event}]: Number of collections: {len(collections)}")
    geoframes = []
    
    for collection in collections:
        geoframe = leafmap.maxar_items(
            collection_id=event, 
            child_id=collection,
            return_gdf=True,
        )
        geoframes.append(geoframe)
    gdf = pd.concat(geoframes)
    intersecting_tiles = gdf.sjoin(regions, how="inner", op="intersects")
    
    print(f"[Download Maxar][{event}]: Download TIFs.")
    for tif_url in intersecting_tiles["visual"].values:
        # Build file path
        scene_date = re.search(r"\d{4}-\d{2}-\d{2}", tif_url).group(0)
        scene_id = Path(tif_url).stem
        fn = f"{event}_{scene_date}_{scene_id}.tif"
        dst_path = dst_dir / fn
        
        # Download TIF
        http = urllib3.PoolManager()
        response = http.request('GET', tif_url)

        print(f"[Download Maxar][{event}]: Save {dst_path.name}")
        # Write TIF
        with open(dst_path, 'wb') as f:
            f.write(response.data)
# Out:
# afghanistan-earthquake22
# The number of collections: 14
# 	10400100737B8400
# 	105001002998D400
# 	10300100C084CC00
# 	10300100C04CC000
# 	10300100BFCFAF00
# 	10300100C028B900
# 	10300100C0C06900
# 	1040010077468F00
# 	10400100777CAA00
# 	10300100D4928800
# 	10300100D5B4AB00
# 	1040010077B01400
# 	10400100779DDF00
# 	105001002CB61600
# 	Save afghanistan-earthquake22_2022-02-04_10400100737B8400-visual.tif.
# 	Save afghanistan-earthquake22_2022-01-31_105001002998D400-visual.tif.
# Gambia-flooding-8-11-2022
# The number of collections: 6
# 	105001002BD68F00
# 	10300100CFC9A500
# 	1040010073D77D00
# 	104001007B1A7600
# 	104001007C806A00
# 	104001007A565700
# 	Save Gambia-flooding-8-11-2022_2022-05-19_105001002BD68F00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-05-19_105001002BD68F00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-05-19_105001002BD68F00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_10300100CFC9A500-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_10300100CFC9A500-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_10300100CFC9A500-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_10300100CFC9A500-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_10300100CFC9A500-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_10300100CFC9A500-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_1040010073D77D00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_1040010073D77D00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-03-15_1040010073D77D00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007C806A00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007C806A00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007C806A00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007C806A00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007C806A00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007C806A00-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007A565700-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007A565700-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007A565700-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007A565700-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007A565700-visual.tif.
# 	Save Gambia-flooding-8-11-2022_2022-08-13_104001007A565700-visual.tif.
# Indonesia-Earthquake22
# The number of collections: 8
# 	105001002EA2FA00
# 	10300100CB626A00
# 	10300100C5655B00
# 	104001006B084C00
# 	10300100C912CA00
# 	10300100DD6AE200
# 	10300100DE2DD700
# 	10300100DE5CCF00
# 	Save Indonesia-Earthquake22_2022-09-14_105001002EA2FA00-visual.tif.
# 	Save Indonesia-Earthquake22_2022-09-14_105001002EA2FA00-visual.tif.
# 	Save Indonesia-Earthquake22_2022-01-04_10300100CB626A00-visual.tif.
# 	Save Indonesia-Earthquake22_2022-01-04_10300100CB626A00-visual.tif.

# %%
# Out:
# '105001002998D400-visual.tif'

# %%
# Out:
# afghanistan-earthquake22_2022-02-04_10400100737B8400-visual.tif
# afghanistan-earthquake22_2022-01-31_105001002998D400-visual.tif

# %%
import boto3

s3 = boto3.client('s3', aws_access_key_id=AWS_ACCESS_KEY, aws_secret_access_key=AWS_SECRET_KEY)
url = 'https://maxar-opendata.s3.amazonaws.com/events/afghanistan-earthquake22/ard/42/120200201331/2022-01-31/105001002998D400-visual.tif'

bucket = url.split('/')[2]
key = '/'.join(url.split('/')[3:])

response = s3.get_object(Bucket=bucket, Key=key)

with open('105001002998D400-visual.tif', 'wb') as f:
    f.write(response['Body'].read())
# Out:
# ---------------------------------------------------------------------------
# NoSuchBucket                              Traceback (most recent call last)
# Cell In[23], line 9
#       6 bucket = url.split('/')[2]
#       7 key = '/'.join(url.split('/')[3:])
# ----> 9 response = s3.get_object(Bucket=bucket, Key=key)
#      11 with open('105001002998D400-visual.tif', 'wb') as f:
#      12     f.write(response['Body'].read())
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\botocore\client.py:530, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     526     raise TypeError(
#     527         f"{py_operation_name}() only accepts keyword arguments."
#     528     )
#     529 # The "self" in this scope is referring to the BaseClient.
# --> 530 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\botocore\client.py:960, in BaseClient._make_api_call(self, operation_name, api_params)
#     958     error_code = parsed_response.get("Error", {}).get("Code")
#     959     error_class = self.exceptions.from_code(error_code)
# --> 960     raise error_class(parsed_response, operation_name)
#     961 else:
#     962     return parsed_response
#
# NoSuchBucket: An error occurred (NoSuchBucket) when calling the GetObject operation: The specified bucket does not exist

# %%
# 8 and 12 are the best
m = leafmap.Map()
for geoframe in geoframes:
    m.add_gdf(geoframe, layer_name=geoframe.catalog_id[0])
m.add_gdf(regions.loc[[event]], layer_name=event)
m

# %%
import datacube
# from stac import STAC
import requests

# Define the area of interest (AOI) as a GeoJSON Polygon
aoi = {
    "type": "Polygon",
    "coordinates": [
        [
            [
                68.77120971679688,
                37.065393740039164
            ],
            [
                69.50531005859375,
                37.065393740039164
            ],
            [
                69.50531005859375,
                37.54569422279954
            ],
            [
                68.77120971679688,
                37.54569422279954
            ],
            [
                68.77120971679688,
                37.065393740039164
            ]
        ]
    ]
}

# Connect to the Data Cube
dc = datacube.Datacube(app='afg-earthquake-2022')

# Define the product and query the Data Cube for available datasets
product = 'maxar-worldview3'
datasets = dc.find_datasets(product=product, geopolygon=aoi)

# Print the number of available datasets
print(f'Found {len(datasets)} datasets')

# # Define the time range of interest
# start_date = '2022-05-01'
# end_date = '2022-06-01'

# # Filter the datasets by the time range of interest
# datasets = list(filter(lambda ds: ds.time.begin < end_date and ds.time.end > start_date, datasets))

# # Print the number of datasets that match the time range
# print(f'Found {len(datasets)} datasets between {start_date} and {end_date}')

# # Get the STAC URL for each dataset
# stac_urls = [ds.metadata_doc['stac_extensions']['eo']['view:single']['assets']['analytic']['href'] for ds in datasets]

# # Download the GeoTIFF files for each dataset
# for url in stac_urls:
#     r = requests.get(url, allow_redirects=True)
#     with open(f'{product}_{start_date}_{end_date}.tif', 'wb') as f:
#         f.write(r.content)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 35
#       6 aoi = {
#       7     "type": "Polygon",
#       8     "coordinates": [
#    (...)
#      31     ]
#      32 }
#      34 # Connect to the Data Cube
# ---> 35 dc = datacube.Datacube(app='afg-earthquake-2022')
#      37 # Define the product and query the Data Cube for available datasets
#      38 product = 'maxar-worldview3'
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\datacube\api\core.py:87, in Datacube.__init__(self, index, config, app, env, validate_connection)
#      84     return config
#      86 if index is None:
# ---> 87     index = index_connect(normalise_config(config),
#      88                           application_name=app,
#      89                           validate_connection=validate_connection)
#      91 self.index = index
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\datacube\api\core.py:81, in Datacube.__init__.<locals>.normalise_config(config)
#      79 def normalise_config(config):
#      80     if config is None:
# ---> 81         return LocalConfig.find(env=env)
#      82     if isinstance(config, str):
#      83         return LocalConfig.find([config], env=env)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\datacube\config.py:133, in LocalConfig.find(cls, paths, env)
#     129     paths = [str(paths)]
#     131 files_loaded = config.read(str(p) for p in paths if p)
# --> 133 return LocalConfig(
#     134     config,
#     135     files_loaded=files_loaded,
#     136     env=env,
#     137 )
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\datacube\config.py:106, in LocalConfig.__init__(self, config, files_loaded, env)
#     104         self._env = fallback_env
#     105         return
# --> 106 raise ValueError('No ODC environment, checked configurations for %s' % fallbacks)
#
# ValueError: No ODC environment, checked configurations for ['default', 'datacube']

# %%
import dask
print("Instantiate dask client.")
client = dask.distributed.Client()
configure_rio(cloud_defaults=True, client=client)
display(client)
# Out:
# Instantiate dask client.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 import dask
#       2 print("Instantiate dask client.")
# ----> 3 client = dask.distributed.Client()
#       4 configure_rio(cloud_defaults=True, client=client)
#       5 display(client)
#
# AttributeError: module 'dask' has no attribute 'distributed'

# %%
# create a client instance for the Maxar STAC API
client = Client.open("https://radiantearth.github.io/stac-browser/#/external/maxar-opendata.s3.amazonaws.com/events/catalog.json")#Client.open("https://api.maxar.com/catalog/v3")

# search for the 'afghanistan-earthquake22' dataset
search = client.search(
    # collections=["maxar-worldview"],
    # bbox=[69.0, 32.0, 75.0, 37.0],
    # datetime="2022-05-01T00:00:00Z/2022-05-31T23:59:59Z",
    # query={"eo:cloud_cover": {"lt": 5}},
    limit=10,
    sortby=["-properties.datetime"],
)

# print the number of items found
# print(f"Found {len(items)} items")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[29], line 2
#       1 # create a client instance for the Maxar STAC API
# ----> 2 client = Client.open("https://radiantearth.github.io/stac-browser/#/external/maxar-opendata.s3.amazonaws.com/events/catalog.json")#Client.open("https://api.maxar.com/catalog/v3")
#       4 # search for the 'afghanistan-earthquake22' dataset
#       5 search = client.search(
#       6     # collections=["maxar-worldview"],
#       7     # bbox=[69.0, 32.0, 75.0, 37.0],
#    (...)
#      11     sortby=["-properties.datetime"],
#      12 )
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\client.py:143, in Client.open(cls, url, headers, parameters, ignore_conformance, modifier, request_modifier, stac_io)
#      80 @classmethod
#      81 def open(
#      82     cls,
#    (...)
#      89     stac_io: Optional[StacApiIO] = None,
#      90 ) -> "Client":
#      91     """Opens a STAC Catalog or API
#      92     This function will read the root catalog of a STAC Catalog or API
#      93
#    (...)
#     141         catalog : A :class:`Client` instance for this Catalog/API
#     142     """
# --> 143     client: Client = cls.from_file(
#     144         url,
#     145         headers=headers,
#     146         parameters=parameters,
#     147         modifier=modifier,
#     148         request_modifier=request_modifier,
#     149         stac_io=stac_io,
#     150     )
#     151     search_link = client.get_search_link()
#     152     # if there is a search link, but no conformsTo advertised, ignore
#     153     # conformance entirely
#     154     # NOTE: this behavior to be deprecated as implementations become conformant
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\client.py:197, in Client.from_file(cls, href, stac_io, headers, parameters, modifier, request_modifier)
#     190 else:
#     191     stac_io.update(
#     192         headers=headers,
#     193         parameters=parameters,
#     194         request_modifier=request_modifier,
#     195     )
# --> 197 client: Client = super().from_file(href, stac_io)
#     199 client._stac_io._conformance = client.extra_fields.get(  # type: ignore
#     200     "conformsTo", []
#     201 )
#     202 client.modifier = modifier
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\catalog.py:1127, in Catalog.from_file(cls, href, stac_io)
#    1124 if stac_io is None:
#    1125     stac_io = pystac.StacIO.default()
# -> 1127 result = super().from_file(href, stac_io)
#    1128 if not isinstance(result, Catalog):
#    1129     raise pystac.STACTypeError(f"{result} is not a {Catalog}.")
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_object.py:562, in STACObject.from_file(cls, href, stac_io)
#     559 if not is_absolute_href(href):
#     560     href = make_absolute_href(href)
# --> 562 d = stac_io.read_json(href)
#     563 o = cls.from_dict(d, href=href, migrate=True, preserve_dict=False)
#     565 # Set the self HREF, if it's not already set to something else.
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:203, in StacIO.read_json(self, source, *args, **kwargs)
#     186 """Read a dict from the given source.
#     187
#     188 See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)
#     200     given source.
#     201 """
#     202 txt = self.read_text(source, *args, **kwargs)
# --> 203 return self.json_loads(txt)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:107, in StacIO.json_loads(self, txt, *args, **kwargs)
#     105     result = orjson.loads(txt)
#     106 else:
# --> 107     result = json.loads(txt, *args, **kwargs)
#     108 return result
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
from pystac_client import Client
url = 'https://maxar-opendata.s3.amazonaws.com/events/catalog.json'
client = Client.open(url)
client.search(datetime='2023-02-01/2023-02-28')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[27], line 4
#       2 url = 'https://maxar-opendata.s3.amazonaws.com/events/catalog.json'
#       3 client = Client.open(url)
# ----> 4 client.search(datetime='2023-02-01/2023-02-28')
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\client.py:442, in Client.search(self, method, max_items, limit, ids, collections, bbox, intersects, datetime, query, filter, filter_lang, sortby, fields)
#     341 """Query the ``/search`` endpoint using the given parameters.
#     342
#     343 This method returns an :class:`~pystac_client.ItemSearch` instance. See that
#    (...)
#     439         a ``"rel"`` type of ``"search"``.
#     440 """
#     441 if not self._conforms_to(ConformanceClasses.ITEM_SEARCH):
# --> 442     raise NotImplementedError(
#     443         "This catalog does not support search because it "
#     444         f'does not conform to "{ConformanceClasses.ITEM_SEARCH}"'
#     445     )
#     446 search_link = self.get_search_link()
#     447 if search_link:
#
# NotImplementedError: This catalog does not support search because it does not conform to "ConformanceClasses.ITEM_SEARCH"

# %%
# madagascar collection = collections[2] == '1040010068610000'
# afghanistan collection = collections[12] =='10400100779DDF00'

# %%
# Out:
# The number of collections: 14
#                                             geometry              datetime
# 0  POLYGON ((69.75352 33.29793, 69.75318 33.25531...  2022-06-24T06:35:58Z  \
# 1  POLYGON ((69.80730 33.30395, 69.80730 33.30395...  2022-06-24T06:35:58Z
# 2  POLYGON ((69.86105 33.30994, 69.86097 33.29971...  2022-06-24T06:35:58Z
# 3  POLYGON ((69.79822 33.30294, 69.80729 33.30288...  2022-06-24T06:35:58Z
# 4  POLYGON ((69.80394 33.30291, 69.80350 33.25499...  2022-06-24T06:35:58Z
#
#   platform   gsd ard_metadata_version        catalog_id  utm_zone
# 0     WV03  0.55                0.0.1  10400100779DDF00        42  \
# 1     WV03  0.55                0.0.1  10400100779DDF00        42
# 2     WV03  0.56                0.0.1  10400100779DDF00        42
# 3     WV03  0.55                0.0.1  10400100779DDF00        42
# 4     WV03  0.56                0.0.1  10400100779DDF00        42
#
#         quadkey  view:off_nadir  view:azimuth  ...  view:sun_azimuth
# 0  120200023323            42.8         256.6  ...             130.2  \
# 1  120200023330            43.0         256.6  ...             130.2
# 2  120200023331            43.2         256.7  ...             130.2
# 3  120200023332            43.0         256.6  ...             130.2
# 4  120200023333            43.2         256.7  ...             130.2
#
#    view:sun_elevation  proj:epsg
# 0                75.9      32642  \
# 1                75.9      32642
# 2                75.9      32642
# 3                75.9      32642
# 4                75.9      32642
#
#                                        proj:geometry              grid:code
# 0  {'type': 'Polygon', 'coordinates': [[[570154.4...  MXRA-Z42-120200023323  \
# 1  {'type': 'Polygon', 'coordinates': [[[575155.6...  MXRA-Z42-120200023330
# 2  {'type': 'Polygon', 'coordinates': [[[580154.1...  MXRA-Z42-120200023331
# 3  {'type': 'Polygon', 'coordinates': [[[574311.8...  MXRA-Z42-120200023332
# 4  {'type': 'Polygon', 'coordinates': [[[574843.7...  MXRA-Z42-120200023333
#
#                                            proj:bbox tile:data_area
# 0  566974.7924804688,3679843.75,570156.25,3684569...           13.8  \
# 1  572101.7456054688,3684843.75,575156.25,3685274...            0.6
# 2  574843.75,3684843.75,580156.25,3685978.6987304688            4.0
# 3          569843.75,3679843.75,575156.25,3685156.25           26.8
# 4          574843.75,3679843.75,580156.25,3685156.25           28.2
#
#    tile:clouds_area  tile:clouds_percent
# 0               0.0                    0  \
# 1               0.0                    0
# 2               0.0                    0
# 3               0.0                    0
# 4               0.0                    0
#
#                                               visual
# 0  https://maxar-opendata.s3.amazonaws.com/events...
# 1  https://maxar-opendata.s3.amazonaws.com/events...
# 2  https://maxar-opendata.s3.amazonaws.com/events...
# 3  https://maxar-opendata.s3.amazonaws.com/events...
# 4  https://maxar-opendata.s3.amazonaws.com/events...
#
# [5 rows x 21 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 regions = gpd.read_file(raw_dir / "regions.geojson")
#
# NameError: name 'raw_dir' is not defined

# %%
# Out:
# Map(center=[20, 0], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_text…

# %%
gdf.visual.iloc[0]
# Out:
# 'https://maxar-opendata.s3.amazonaws.com/events/afghanistan-earthquake22/ard/42/120200023323/2022-06-24/10400100779DDF00-visual.tif'

# %%
gdf.to_crs(4326).to_file("em.geojson", driver="GeoJSON")

# %%
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17f0f020ac7d137ff98a851a3c30ab43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17f0f020ac7d137ff98a851a3c30ab43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17f0f020ac7d137ff98a851a3c30ab43 = L.map(
#                 &quot;map_17f0f020ac7d137ff98a851a3c30ab43&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_17f0f020ac7d137ff98a851a3c30ab43);
#
#
#
#
#
#             var tile_layer_4a4d826936cd4c6ce1b8a4547ea1315e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_17f0f020ac7d137ff98a851a3c30ab43);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_17f0f020ac7d137ff98a851a3c30ab43);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_17f0f020ac7d137ff98a851a3c30ab43
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_e862f0252aa89d3c214b80a0817e0d36 = new L.Control.Draw(
#                 options
#             ).addTo( map_17f0f020ac7d137ff98a851a3c30ab43 );
#             map_17f0f020ac7d137ff98a851a3c30ab43.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_17f0f020ac7d137ff98a851a3c30ab43.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_64d2703c2a6fdc125f24829ac6e05955 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_17f0f020ac7d137ff98a851a3c30ab43.addControl(measure_control_64d2703c2a6fdc125f24829ac6e05955);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_17f0f020ac7d137ff98a851a3c30ab43.setView(e.geocode.center, 11);
#             }).addTo(map_17f0f020ac7d137ff98a851a3c30ab43);
#
#
#
#             map_17f0f020ac7d137ff98a851a3c30ab43.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#         function geo_json_e79a77f848ba17c92925474d5e7c6b14_styler(feature) {
#             switch(feature.id) {
#                 default:

# %%
gdf.head(1)
# Out:
#                                             geometry              datetime
# 0  POLYGON ((69.75352 33.29793, 69.75318 33.25531...  2022-06-24T06:35:58Z  \
#
#   platform   gsd ard_metadata_version        catalog_id  utm_zone
# 0     WV03  0.55                0.0.1  10400100779DDF00        42  \
#
#         quadkey  view:off_nadir  view:azimuth  ...  view:sun_azimuth
# 0  120200023323            42.8         256.6  ...             130.2  \
#
#    view:sun_elevation  proj:epsg
# 0                75.9      32642  \
#
#                                        proj:geometry              grid:code
# 0  {'type': 'Polygon', 'coordinates': [[[570154.4...  MXRA-Z42-120200023323  \
#
#                                            proj:bbox tile:data_area
# 0  566974.7924804688,3679843.75,570156.25,3684569...           13.8  \
#
#    tile:clouds_area  tile:clouds_percent
# 0               0.0                    0  \
#
#                                               visual
# 0  https://maxar-opendata.s3.amazonaws.com/events...
#
# [1 rows x 21 columns]

# %%
images = gdf['visual'].tolist()
images[:5]
# Out:
# ['https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133010322/2023-02-07/1050050044DE7E00-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133010323/2023-02-07/1050050044DE7E00-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133010332/2023-02-07/1050050044DE7E00-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133010333/2023-02-07/1050050044DE7E00-visual.tif',
#  'https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133011222/2023-02-07/1050050044DE7E00-visual.tif']

# %%
m = leafmap.Map()
m.add_cog_layer('https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133010322/2023-02-07/1050050044DE7E00-visual.tif')
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7478a5ffc1b74cb402b0eb5d3c45798 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7478a5ffc1b74cb402b0eb5d3c45798&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7478a5ffc1b74cb402b0eb5d3c45798 = L.map(
#                 &quot;map_e7478a5ffc1b74cb402b0eb5d3c45798&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_e7478a5ffc1b74cb402b0eb5d3c45798);
#
#
#
#
#
#             var tile_layer_3a4ebbbd986d708dc346e95c373ab6ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e7478a5ffc1b74cb402b0eb5d3c45798);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_e7478a5ffc1b74cb402b0eb5d3c45798);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_e7478a5ffc1b74cb402b0eb5d3c45798
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_af71cd18dc87d89bf8018dfdc09686ad = new L.Control.Draw(
#                 options
#             ).addTo( map_e7478a5ffc1b74cb402b0eb5d3c45798 );
#             map_e7478a5ffc1b74cb402b0eb5d3c45798.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_e7478a5ffc1b74cb402b0eb5d3c45798.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_df82ea2c6ac7b2d870f702ec99283658 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_e7478a5ffc1b74cb402b0eb5d3c45798.addControl(measure_control_df82ea2c6ac7b2d870f702ec99283658);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_e7478a5ffc1b74cb402b0eb5d3c45798.setView(e.geocode.center, 11);
#             }).addTo(map_e7478a5ffc1b74cb402b0eb5d3c45798);
#
#
#
#             map_e7478a5ffc1b74cb402b0eb5d3c45798.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_40ef049f7ecd96241680d51c6afa7cc8 = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fmaxar-opendata.s3.amazonaws.com%2Fevents%2FKahramanmaras-turkey-earthquake-23%2Fard%2F37%2F031133010322%2F2023-02-07%2F1050050044DE7E00-visual.tif\u0026bidx=1\u0026bidx=2\u0026bidx=3\u0026rescale=7.0%2C240.0\u0026rescale=6.0%2C236.0\u0026rescale=10.0%2C236.0&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 100, &quot;maxZoom&quot;: 100, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subd

# %%
url = 'https://maxar-opendata.s3.amazonaws.com/events/Kahramanmaras-turkey-earthquake-23/ard/37/031133010322/2023-02-07/1050050044DE7E00.json'
m2 = leafmap.Map()
m2.add_stac_layer(url, name="False color")
m2
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f71ce82ca11b53317bee5526d8c41405 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/ljagis/leaflet-measure@2.1.7/dist/leaflet-measure.min.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f71ce82ca11b53317bee5526d8c41405&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f71ce82ca11b53317bee5526d8c41405 = L.map(
#                 &quot;map_f71ce82ca11b53317bee5526d8c41405&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     drawExport: false,
#                     layersControl: true,
#                 }
#             );
#             L.control.scale().addTo(map_f71ce82ca11b53317bee5526d8c41405);
#
#
#
#
#
#             var tile_layer_987c6f1b0ccc7b54c3a0dc956c963d23 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f71ce82ca11b53317bee5526d8c41405);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_f71ce82ca11b53317bee5526d8c41405);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_f71ce82ca11b53317bee5526d8c41405
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_cab989cc616a9bf577cfc4d4cc5b7d81 = new L.Control.Draw(
#                 options
#             ).addTo( map_f71ce82ca11b53317bee5526d8c41405 );
#             map_f71ce82ca11b53317bee5526d8c41405.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_f71ce82ca11b53317bee5526d8c41405.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             var measure_control_7d8e100627584ea9b444d5e016b02a59 = new L.Control.Measure(
#                 {&quot;position&quot;: &quot;bottomleft&quot;, &quot;primaryAreaUnit&quot;: &quot;sqmeters&quot;, &quot;primaryLengthUnit&quot;: &quot;meters&quot;, &quot;secondaryAreaUnit&quot;: &quot;acres&quot;, &quot;secondaryLengthUnit&quot;: &quot;miles&quot;});
#             map_f71ce82ca11b53317bee5526d8c41405.addControl(measure_control_7d8e100627584ea9b444d5e016b02a59);
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_f71ce82ca11b53317bee5526d8c41405.setView(e.geocode.center, 11);
#             }).addTo(map_f71ce82ca11b53317bee5526d8c41405);
#
#
#
#             map_f71ce82ca11b53317bee5526d8c41405.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_52d8fbd28c6cb63e77ff0f30698984c5 = L.tileLayer(
#                 &quot;https://titiler.xyz/stac/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fmaxar-opendata.s3.amazonaws.com%2Fevents%2FKahramanmaras-turkey-earthquake-23%2Fard%2F37%2F031133010322%2F2023-02-07%2F1050050044DE7E00.json\u0026assets=ms_analytic\u0026assets=pan_analytic\u0026assets=visual\u0026rescale=6.0%2C5478.0&quot;,
#                 {&quot;attribution&quot;: &quot;.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 100, &quot;maxZoom&quot;: 100, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1.0, &quot;subdomains&quot;: &quot;abc

# %%
url = "https://maxar-opendata.s3.amazonaws.com/events/catalog.json"
# Out:
# ['1050050044DE7E00',
#  '1050050044DE7F00',
#  '1040010082B85E00',
#  '1040010082698700',
#  '10300500D8F90C00',
#  '104001007E564300',
#  '104001007DAE2D00',
#  '10500500F0DD9700',
#  '10300100DD62DB00',
#  '10300100E1700300',
#  '10300100E18A1000',
#  '1040010077137900',
#  '1040010067C49900',
#  '10300100DF1DB000',
#  '10300100D6740900',
#  '10300500BFF94800',
#  '10200100B5C3A800',
#  '104001008058CD00',
#  '10300100DF6BFE00',
#  '10300100D76F1300',
#  '10300100D6789800',
#  '10300500BFF95000',
#  '10300100DC08C900',
#  '10300100DB913300',
#  '104001006D138700',
#  '10300100D797E100',
#  '10300100DF069700',
#  '10300500BFF94C00',
#  '10300100DFA9DD00',
#  '10300100E0287700',
#  '10300500D9F8CC00',
#  '10300500D9F8D100',
#  '10300500D9F8D500',
#  '1040010082B85E00',
#  '10300500D9F8D200',
#  '10300500D9F8D400',
#  '10300100E2B30500',
#  '10300500D9F8E600',
#  '10300100E2901100',
#  '10300100E131D000',
#  '10300100E29F9100',
#  '10300100E131D000',
#  '10300100E18CB600',
#  '10300100E1B9D900',
#  '10300100E2A73B00',
#  '104001008314FC00',
#  '10300100E2226200',
#  '10300100E291D100',
#  '10300100E19A4400',
#  '10300100E26DC400',
#  '1040010082990000',
#  '10300100E20A6300',
#  '10300100E32E3D00',
#  '10300100E3D52E00']

# %%
import pystac
import requests

# Define the STAC API URL for the Maxar Open Data Catalog
catalog_url = "https://maxar-opendata.s3.amazonaws.com/events/catalog.json"

# Load the catalog into a pystac Catalog object
catalog = pystac.Catalog.from_file(catalog_url)

# Get the specific event you want to download data for
event_id = "cyclone-emnati22"
event = catalog.get_item(event_id)

# Get the assets for the event
assets = event.assets

# Select the asset you want to download (e.g., the RGB image)
asset_key = "image:visual"
asset = assets[asset_key]

# Download the asset
response = requests.get(asset.href)

# Save the asset to disk
with open(f"{event_id}.tif", "wb") as f:
    f.write(response.content)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[20], line 15
#      12 event = catalog.get_item(event_id)
#      14 # Get the assets for the event
# ---> 15 assets = event.assets
#      17 # # Select the asset you want to download (e.g., the RGB image)
#      18 # asset_key = "image:visual"
#      19 # asset = assets[asset_key]
#    (...)
#      25 # with open(f"{event_id}.tif", "wb") as f:
#      26 #     f.write(response.content)
#
# AttributeError: 'NoneType' object has no attribute 'assets'

# %%
import pystac
import requests

# Define the STAC API URL for the Maxar Open Data Catalog
catalog_url = "https://prd-tnm.s3.amazonaws.com/maxar-catalog/catalog.json"

# Load the catalog into a pystac Catalog object
catalog = pystac.Catalog.from_file(catalog_url)

# Get the specific event you want to download data for
event_id = "2021-biden-inauguration"
event = catalog.get_item(event_id)

# Get the assets for the event
assets = event.assets

# Select the asset you want to download (e.g., the RGB image)
asset_key = "image:visual"
asset = assets[asset_key]

# Download the asset
response = requests.get(asset.href)

# Save the asset to disk
with open(f"{event_id}.tif", "wb") as f:
    f.write(response.content)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:296, in DefaultStacIO.read_text_from_href(self, href)
#     295 req = Request(href, headers=self.headers)
# --> 296 with urlopen(req) as f:
#     297     href_contents = f.read().decode("utf-8")
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     562 args = (dict, 'default', 'http_error_default') + orig_args
# --> 563 return self._call_chain(*args)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     495 func = getattr(handler, meth_name)
# --> 496 result = func(*args)
#     497 if result is not None:
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: Not Found
#
# The above exception was the direct cause of the following exception:
#
# Exception                                 Traceback (most recent call last)
# Cell In[127], line 8
#       5 catalog_url = "https://prd-tnm.s3.amazonaws.com/maxar-catalog/catalog.json"
#       7 # Load the catalog into a pystac Catalog object
# ----> 8 catalog = pystac.Catalog.from_file(catalog_url)
#      10 # Get the specific event you want to download data for
#      11 event_id = "2021-biden-inauguration"
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\catalog.py:1127, in Catalog.from_file(cls, href, stac_io)
#    1124 if stac_io is None:
#    1125     stac_io = pystac.StacIO.default()
# -> 1127 result = super().from_file(href, stac_io)
#    1128 if not isinstance(result, Catalog):
#    1129     raise pystac.STACTypeError(f"{result} is not a {Catalog}.")
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_object.py:562, in STACObject.from_file(cls, href, stac_io)
#     559 if not is_absolute_href(href):
#     560     href = make_absolute_href(href)
# --> 562 d = stac_io.read_json(href)
#     563 o = cls.from_dict(d, href=href, migrate=True, preserve_dict=False)
#     565 # Set the self HREF, if it's not already set to something else.
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:202, in StacIO.read_json(self, source, *args, **kwargs)
#     185 def read_json(self, source: HREF, *args: Any, **kwargs: Any) -> Dict[str, Any]:
#     186     """Read a dict from the given source.
#     187
#     188     See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)
#     200         given source.
#     201     """
# --> 202     txt = self.read_text(source, *args, **kwargs)
#     203     return self.json_loads(txt)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:279, in DefaultStacIO.read_text(self, source, *_, **__)
#     274 """A concrete implementation of :meth:`StacIO.read_text
#     275 <pystac.StacIO.read_text>`. Converts the ``source`` argument to a string (if it
#     276 is not already) and delegates to :meth:`DefaultStacIO.read_text_from_href` for
#     277 opening and reading the file."""
#     278 href = str(os.fspath(source))
# --> 279 return self.read_text_from_href(href)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:299, in DefaultStacIO.read_text_from_href(self, href)
#     297             href_contents = f.read().decode("utf-8")
#     298     except HTTPError as e:
# --> 299         raise Exception("Could not read uri {}".format(href)) from e
#     300 else:
#     301     with open(href, encoding="utf-8") as f:
#
# Exception: Could not read uri https://prd-tnm.s3.amazonaws.com/maxar-catalog/catalog.json

# %% [markdown]
# # Start

# %%
from datetime import datetime
import json
import os
from pathlib import Path

import boto3
import dask

from dotenv import load_dotenv
import geopandas as gpd
import getpass
import hvplot.xarray
from joblib import Parallel, delayed
import pandas as pd
import planetary_computer
from pystac_client import Client
import rasterio as rio
from rasterio.mask import mask as rio_mask
from rasterio.session import AWSSession
import rioxarray
import stackstac
import xarray as xr

def get_raster(s3_link, geom, chunks="auto", drop=True):
    try:
        da = rioxarray.open_rasterio(s3_link, chunks="auto").squeeze('band', drop=True).rio.clip([geom])
        print("*", end="")
        return da
    except Exception as e:
        print(f"\nLink failed: {s3_link}")
        print(e)
        return None


def time_index_from_filenames(file_links):
    '''
    Helper function to create a pandas DatetimeIndex
    '''
    return [datetime.strptime(f.split('.')[-5], '%Y%jT%H%M%S') for f in file_links]


load_dotenv()
USGS_API_KEY = os.environ["USGS_API_KEY"]
USGS_TOKEN_NAME = os.environ["USGS_TOKEN_NAME"]
USGS_USERNAME = os.environ["USGS_USERNAME"]
USGS_PASSWORD = os.environ["USGS_PASSWORD"]
AWS_ACCESS_KEY = os.environ["AWS_ACCESS_KEY"]
AWS_SECRET_KEY = os.environ["AWS_SECRET_KEY"]
NASA_EARTHDATA_S3_ACCESS_KEY = os.environ["NASA_EARTHDATA_S3_ACCESS_KEY"]
NASA_EARTHDATA_S3_SECRET_KEY = os.environ["NASA_EARTHDATA_S3_SECRET_KEY"]
NASA_EARTHDATA_S3_SESSION = os.environ["NASA_EARTHDATA_S3_SESSION"]
NASA_EARTHDATA_USERNAME = os.environ["NASA_EARTHDATA_USERNAME"]
NASA_EARTHDATA_PASSWORD = os.environ["NASA_EARTHDATA_PASSWORD"]

DATA_DIR = Path(r"C:\Users\Peter\gh\rasmussen-705.603\data\ResearchPaper")
AOI = "baltimore_cnn"

data_dir = DATA_DIR / AOI

raw_dir = data_dir / "raw"
interim_dir = data_dir / "interim"

raw_dir.mkdir(exist_ok=True, parents=True)
interim_dir.mkdir(exist_ok=True, parents=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[137], line 20
#      18 from rasterio.mask import mask as rio_mask
#      19 from rasterio.session import AWSSession
# ---> 20 import rioxarray
#      21 import stackstac
#      22 import xarray as xr
#
# ModuleNotFoundError: No module named 'rioxarray'

# %%
import pystac
from pystac_client import Client

# Set up the client
client = Client.open('https://api.stac.maxar.com/v2')

# # Get the catalog for Maxar open data
# catalog = client.get_catalog()

# # Get the collection for Maxar open data's WorldView imagery
# collection = catalog.get_child('maxar-worldview')

# # Get the items for the "cyclone-emnati22" event
# items = collection.get_items(filter={
#     'collections': 'maxar-worldview',
#     'properties': {
#         'event': 'cyclone-emnati22'
#     }
# })

# # Print the number of items found
# print(f"Found {len(items)} items for 'cyclone-emnati22':")

# # Print the IDs of the items found
# for item in items:
#     print(f"- {item.id}")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\util\connection.py:72, in create_connection(address, timeout, source_address, socket_options)
#      68     return six.raise_from(
#      69         LocationParseError(u"'%s', label empty or too long" % host), None
#      70     )
# ---> 72 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      73     af, socktype, proto, canonname, sa = res
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connection.py:363, in HTTPSConnection.connect(self)
#     361 def connect(self):
#     362     # Add certificate verification
# --> 363     self.sock = conn = self._new_conn()
#     364     hostname = self.host
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connection.py:186, in HTTPConnection._new_conn(self)
#     185 except SocketError as e:
# --> 186     raise NewConnectionError(
#     187         self, "Failed to establish a new connection: %s" % e
#     188     )
#     190 return conn
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x000001EE8EBDE6B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     488 if not chunked:
# --> 489     resp = conn.urlopen(
#     490         method=request.method,
#     491         url=url,
#     492         body=request.body,
#     493         headers=request.headers,
#     494         redirect=False,
#     495         assert_same_host=False,
#     496         preload_content=False,
#     497         decode_content=False,
#     498         retries=self.max_retries,
#     499         timeout=timeout,
#     500     )
#     502 # Send the request.
#     503 else:
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\urllib3\util\retry.py:592, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     591 if new_retry.is_exhausted():
# --> 592     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     594 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='api.stac.maxar.com', port=443): Max retries exceeded with url: /v2 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001EE8EBDE6B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\stac_api_io.py:167, in StacApiIO.request(self, href, method, headers, parameters)
#     166     logger.debug(msg)
# --> 167     resp = self.session.send(prepped)
#     168 except Exception as err:
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\requests\adapters.py:565, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     563         raise SSLError(e, request=request)
# --> 565     raise ConnectionError(e, request=request)
#     567 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='api.stac.maxar.com', port=443): Max retries exceeded with url: /v2 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001EE8EBDE6B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# During handling of the above exception, another exception occurred:
#
# APIError                                  Traceback (most recent call last)
# Cell In[130], line 5
#       2 from pystac_client import Client
#       4 # Set up the client
# ----> 5 client = Client.open('https://api.stac.maxar.com/v2')
#       7 # # Get the catalog for Maxar open data
#       8 # catalog = client.get_catalog()
#       9
#    (...)
#      25 # for item in items:
#      26 #     print(f"- {item.id}")
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\client.py:143, in Client.open(cls, url, headers, parameters, ignore_conformance, modifier, request_modifier, stac_io)
#      80 @classmethod
#      81 def open(
#      82     cls,
#    (...)
#      89     stac_io: Optional[StacApiIO] = None,
#      90 ) -> "Client":
#      91     """Opens a STAC Catalog or API
#      92     This function will read the root catalog of a STAC Catalog or API
#      93
#    (...)
#     141         catalog : A :class:`Client` instance for this Catalog/API
#     142     """
# --> 143     client: Client = cls.from_file(
#     144         url,
#     145         headers=headers,
#     146         parameters=parameters,
#     147         modifier=modifier,
#     148         request_modifier=request_modifier,
#     149         stac_io=stac_io,
#     150     )
#     151     search_link = client.get_search_link()
#     152     # if there is a search link, but no conformsTo advertised, ignore
#     153     # conformance entirely
#     154     # NOTE: this behavior to be deprecated as implementations become conformant
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\client.py:197, in Client.from_file(cls, href, stac_io, headers, parameters, modifier, request_modifier)
#     190 else:
#     191     stac_io.update(
#     192         headers=headers,
#     193         parameters=parameters,
#     194         request_modifier=request_modifier,
#     195     )
# --> 197 client: Client = super().from_file(href, stac_io)
#     199 client._stac_io._conformance = client.extra_fields.get(  # type: ignore
#     200     "conformsTo", []
#     201 )
#     202 client.modifier = modifier
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\catalog.py:1127, in Catalog.from_file(cls, href, stac_io)
#    1124 if stac_io is None:
#    1125     stac_io = pystac.StacIO.default()
# -> 1127 result = super().from_file(href, stac_io)
#    1128 if not isinstance(result, Catalog):
#    1129     raise pystac.STACTypeError(f"{result} is not a {Catalog}.")
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_object.py:562, in STACObject.from_file(cls, href, stac_io)
#     559 if not is_absolute_href(href):
#     560     href = make_absolute_href(href)
# --> 562 d = stac_io.read_json(href)
#     563 o = cls.from_dict(d, href=href, migrate=True, preserve_dict=False)
#     565 # Set the self HREF, if it's not already set to something else.
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac\stac_io.py:202, in StacIO.read_json(self, source, *args, **kwargs)
#     185 def read_json(self, source: HREF, *args: Any, **kwargs: Any) -> Dict[str, Any]:
#     186     """Read a dict from the given source.
#     187
#     188     See :func:`StacIO.read_text <pystac.StacIO.read_text>` for usage of
#    (...)
#     200         given source.
#     201     """
# --> 202     txt = self.read_text(source, *args, **kwargs)
#     203     return self.json_loads(txt)
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\stac_api_io.py:123, in StacApiIO.read_text(self, source, *args, **kwargs)
#     121 href = str(source)
#     122 if _is_url(href):
# --> 123     return self.request(href, *args, **kwargs)
#     124 else:
#     125     with open(href) as f:
#
# File c:\Users\Peter\anaconda3\envs\leafmap\lib\site-packages\pystac_client\stac_api_io.py:169, in StacApiIO.request(self, href, method, headers, parameters)
#     167     resp = self.session.send(prepped)
#     168 except Exception as err:
# --> 169     raise APIError(str(err))
#     170 if resp.status_code != 200:
#     171     raise APIError.from_response(resp)
#
# APIError: HTTPSConnectionPool(host='api.stac.maxar.com', port=443): Max retries exceeded with url: /v2 (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x000001EE8EBDE6B0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
